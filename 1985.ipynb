# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
df=pd.read_csv('auto_clean.csv')

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df[['engine-size','stroke','highway-mpg','price','peak-rpm']].corr()
# Out:
#              engine-size    stroke  highway-mpg     price  peak-rpm
# engine-size     1.000000  0.209523    -0.679571  0.872335 -0.256733
# stroke          0.209523  1.000000    -0.035201  0.082310 -0.065713
# highway-mpg    -0.679571 -0.035201     1.000000 -0.704692 -0.058598
# price           0.872335  0.082310    -0.704692  1.000000 -0.101616
# peak-rpm       -0.256733 -0.065713    -0.058598 -0.101616  1.000000

# %%
##plotting

# %%
sns.regplot(x='engine-size',y='price',data=df)
plt.show()           ## we can interpret from the plot that as the engine-size increase ,
                     ##the price of the vehical alos increade

# %%
sns.regplot(x='stroke',y='price',data=df)
plt.show()

# %%
sns.regplot(x='highway-mpg',y='price',data=df)   ## faster cars have low mpg and higher price 
                                                  ##which is quite clear from the below plot
plt.show()

# %%
sns.regplot(x='peak-rpm',y='price',data=df) ###
plt.show()

# %%
## from the bove analysis it is clear that engine-size and highway-mpg of a car can distinduish the data quite well

# %%
## now we can check how the factors other than the ones related to engines influnce the price 
## of a vehicle

# %%
## Since the other variable are mainly categorical ,we prefer boxplot for better visual analysis.

# %%
sns.boxplot(x='body-style',y='price',data=df)

# %%
sns.boxplot(x='drive-wheels',y='price',data=df)

# %%
sns.boxplot(x='engine-location',y='price',data=df)

# %%
# Descriptive Statistical Analysis#

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
df['body-style'].value_counts()
# Out:
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
df['engine-location'].value_counts() ## since in the dataset there are only
## three rear wheel drive ,it  is difficult to predict using this
# Out:
# front    198
# rear       3
# Name: engine-location, dtype: int64

# %% [raw]
# # Model Development

# %% [raw]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x=df[['highway-mpg']]
y=df[['price']]

# %%
lm.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# array([38423.30585816])

# %%
lm.coef_
# Out:
# array([[-821.73337832]])

# %%
lm.predict([[27]])
# Out:
# array([[16236.50464347]])

# %%
x_data=df.drop('price',axis=1)

# %%
x_data
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
y_data=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(x_data,y_data,test_size=0.3,random_state=1)

# %%
print(X_test.shape[0])
print(X_train.shape[0])
# Out:
# 61
# 140

# %%
lre=LinearRegression()

# %%
lre.fit(X_train[['horsepower']],y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lre.score(X_test[['horsepower']], y_test)
# Out:
# 0.6287485044222196

# %%
from  sklearn.model_selection import cross_val_score

# %%
Rcross=cross_val_score(lre,x_data[['horsepower']], y_data, cv=4)

# %%
Rcross
# Out:
# array([0.7746232 , 0.51716687, 0.74785353, 0.04839605])

# %%
Rcross.mean()
# Out:
# 0.522009915042119
